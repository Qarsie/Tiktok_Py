# %%
# =======================================================
# 6. AI-Driven Trend Forecasting
# Goal: Predict the next viral trends on TikTok using ML
# =======================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.combine import SMOTETomek

# --- 1. Load Data ---
df = pd.read_csv('data/processed/tiktok_processed_with_nlp_features.csv', parse_dates=['create_time'])
df['clean_description'] = df['clean_description'].fillna("").astype(str)
df['create_time'] = pd.to_datetime(df['create_time'])
df = df.sort_values('create_time')

# --- 2. Define Features ---
numerical_features = [
    'likes', 'comments', 'shares', 'plays', 'hashtag_count',
    'description_length', 'sentiment_polarity'
]
categorical_features = ['author', 'day_of_week', 'is_weekend', 'time_period']
text_feature = 'clean_description'

# --- 3. Define Viral Threshold ---
threshold = df['virality_score_normalized'].quantile(0.80)
df['is_viral'] = (df['virality_score_normalized'] >= threshold).astype(int)

# --- 4. Label Future Viral Videos (24h and 7d) ---
def label_viral_next_period(df, period_hours):
    df_sorted = df.sort_values('create_time')
    df_sorted['future_virality'] = df_sorted.groupby('author')['virality_score_normalized'].shift(-1)
    df_sorted['future_time'] = df_sorted.groupby('author')['create_time'].shift(-1)
    df_sorted['delta_hours'] = (df_sorted['future_time'] - df_sorted['create_time']).dt.total_seconds() / 3600
    # Only consider future videos within the period
    mask = (df_sorted['delta_hours'] > 0) & (df_sorted['delta_hours'] <= period_hours)
    df_sorted['is_viral_next'] = ((df_sorted['future_virality'] >= threshold) & mask).astype(int)
    return df_sorted

df_24h = label_viral_next_period(df, 24)
df_7d = label_viral_next_period(df, 24*7)

# --- 5. Preprocessing Pipeline ---
preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), numerical_features),
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features),
    ('txt', TfidfVectorizer(max_features=50, stop_words='english'), text_feature)
])

selector = SelectKBest(score_func=f_classif, k=30)

def run_trend_forecasting(df_labeled, target_col, preprocessor, selector, base_model):
    feature_cols = numerical_features + categorical_features + [text_feature]
    df_valid = df_labeled[df_labeled[target_col].notna()].copy()
    X = df_valid[feature_cols]
    y = df_valid[target_col]
    # Stratified split to preserve class balance
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, stratify=y, random_state=42
    )

    # Preprocessing
    X_train_proc = preprocessor.fit_transform(X_train)
    X_test_proc = preprocessor.transform(X_test)

    # Use SMOTETomek for better balancing
    smote = SMOTETomek(random_state=42)
    X_train_res, y_train_res = smote.fit_resample(X_train_proc, y_train)

    # Feature selection
    selector.fit(X_train_res, y_train_res)
    X_train_sel = selector.transform(X_train_res)
    X_test_sel = selector.transform(X_test_proc)

    # Train model
    model = base_model
    model.fit(X_train_sel, y_train_res)
    y_proba = model.predict_proba(X_test_sel)[:, 1]
    # Try a lower threshold for positive class
    threshold_pred = 0.3
    y_pred = (y_proba >= threshold_pred).astype(int)

    # Evaluation
    print(f"\n--- {target_col} ---")
    print("ROC-AUC:", roc_auc_score(y_test, y_proba))
    print(classification_report(y_test, y_pred))

    # ROC Curve
    plt.figure()
    fpr, tpr, _ = roc_curve(y_test, y_proba)
    plt.plot(fpr, tpr, label=f'AUC = {roc_auc_score(y_test, y_proba):.3f}')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - {target_col}')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Output: Top viral predictions as DataFrame
    X_test_index = y_test.index
    viral_videos = df_valid.loc[X_test_index].copy()
    viral_videos['predicted_proba'] = y_proba
    viral_videos['predicted_label'] = y_pred
    viral_output = viral_videos[viral_videos['predicted_label'] == 1][['video_id', 'create_time', 'clean_description', 'author','hashtag_list', 'hashtag_count', 'predicted_proba']]
    viral_output = viral_output.sort_values(by='predicted_proba', ascending=False).head(10)
    return viral_output

# --- 6. Filter Valid Rows ---
df_24h_valid = df_24h[df_24h['is_viral_next'].notna()].copy()
df_7d_valid = df_7d[df_7d['is_viral_next'].notna()].copy()

# --- 7. Run Forecasting for 24h and 7d ---
base_model = RandomForestClassifier(n_estimators=100, max_depth=7, random_state=42, class_weight='balanced', n_jobs=-1)
top_viral_24h = run_trend_forecasting(df_24h_valid, 'is_viral_next', preprocessor, selector, base_model)
top_viral_7d = run_trend_forecasting(df_7d_valid, 'is_viral_next', preprocessor, selector, base_model)

print("\nTop viral predictions for next 24 hours:")
display(top_viral_24h)

print("\nTop viral predictions for next 7 days:")
display(top_viral_7d)
# Out:
# --- is_viral_next ---
# ROC-AUC: 0.6404728789986092
#               precision    recall  f1-score   support
#
#            0       0.99      0.87      0.93      1438
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.87      1445
#    macro avg       0.50      0.43      0.46      1445
# weighted avg       0.99      0.87      0.92      1445
# --- is_viral_next ---
# ROC-AUC: 0.7476819454163751
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60      1429
#            1       0.02      0.88      0.03        16
#
#     accuracy                           0.44      1445
#    macro avg       0.51      0.65      0.32      1445
# weighted avg       0.99      0.44      0.60      1445
# Top viral predictions for next 24 hours:
#                  video_id         create_time  \
# 4429  7506851389063154986 2025-05-21 10:57:39
# 4616  7506931134190701867 2025-05-21 16:07:04
# 4688  7506954008288873758 2025-05-21 17:35:48
# 3403  7506362355480071455 2025-05-20 03:19:57
# 6919  7507756543157226798 2025-05-23 21:30:32
# 7032  7507716639991794949 2025-05-24 00:30:00
# 6324  7507463779257552150 2025-05-23 02:34:02
# 4741  7506968899187985710 2025-05-21 18:33:34
# 5565  7507276122527223070 2025-05-22 14:25:44
# 5826  7507341701648796958 2025-05-22 18:40:11
#
#                                       clean_description                author  \
# 4429  have you watched this like movie goviral blowu...               tianye7
# 4616                                       movie tiktok              cocolill
# 4688  please tiktok do your thing my buddy just past...         that_truck360
# 3403                                      tiktok foryou          dgvizao48242
# 6919     this is a good prank  barstool gametime viaken        barstoolsports
# 7032  en larosa dayana se niega a tener a su bebé   ...  larosadeguadalupe.of
# 6324                                     fyp olliespark            olliespark
# 4741  dyeing my moms hair mexican mom edition using ...           itatilopez_
# 5565                              help tiktok movie fyp           yxlstjkppaa
# 5826                            tiktok fyp tvshow movie        stachiakristal
#
#                                            hashtag_list  hashtag_count  \
# 4429                                            ['fyp']              1
# 4616                                ['movie', 'tiktok']              2
# 4688                                                 []              0
# 3403                               ['tiktok', 'foryou']              2
# 6919                                                 []              0
# 7032  ['larosa', 'originales', 'larosadeguadalupe', ...              5
# 6324                              ['fyp', 'olliespark']              2
# 4741  ['garnierpartner', 'garnierbelike', 'hispanics...              4
# 5565                 ['help', 'tiktok', 'movie', 'fyp']              4
# 5826               ['tiktok', 'fyp', 'tvshow', 'movie']              4
#
#       predicted_proba
# 4429         0.698030
# 4616         0.689385
# 4688         0.600665
# 3403         0.536081
# 6919         0.535388
# 7032         0.530853
# 6324         0.526768
# 4741         0.515948
# 5565         0.514140
# 5826         0.514140
# Top viral predictions for next 7 days:
#                  video_id         create_time  \
# 6401  7507488759928229166 2025-05-23 04:11:36
# 5234  7507087862320467243 2025-05-22 02:15:41
# 1159  7505112661512686890 2025-05-16 18:30:24
# 678   7502464724584516906 2025-05-09 15:15:59
# 5602  7507289157589503278 2025-05-22 15:16:22
# 4440  7506861542957255982 2025-05-21 11:37:00
# 4219  7506707900849589534 2025-05-21 01:40:42
# 3796  7506513370888277294 2025-05-20 17:55:00
# 3630  7506534058143255838 2025-05-20 14:26:24
# 6296  7507456276838796574 2025-05-23 02:04:55
#
#                                       clean_description          author  \
# 6401                  the replay  i cant even viaevalyn  barstoolsports
# 5234           doggo was nosey  i cant even viabaddie j  barstoolsports
# 1159     core memory  pat bev pod viamontgomery m jamie  barstoolsports
# 678                 besties fr  bffs pod viala_guera_ig  barstoolsports
# 5602  no ipad kid detected  barstool gametime viaire...  barstoolsports
# 4440                           tiktok fouryou movie fyp      zzzjmovies
# 4219  randle has five s just in the h  nba nbaplayof...             nba
# 3796         foryou movie tiktok usa foryoupage cartoon       hugenttop
# 3630                         fypシviral tiktok movie omg        uhfcre57
# 6296  wnba basketball indianafever caitlinclark rhyn...            espn
#
#                                            hashtag_list  hashtag_count  \
# 6401                                                 []              0
# 5234                                                 []              0
# 1159                                                 []              0
# 678                                                  []              0
# 5602                                                 []              0
# 4440              ['tiktok', 'fouryou', 'movie', 'fyp']              4
# 4219  ['nba', 'nbaplayoffs', 'basketball', 'timberwo...              5
# 3796                                        ['cartoon']              1
# 3630            ['fypシviral', 'tiktok', 'movie', 'omg']              4
# 6296  ['wnba', 'basketball', 'indianafever', 'caitli...              5
#
#       predicted_proba
# 6401         0.800647
# 5234         0.800647
# 1159         0.800647
# 678          0.800647
# 5602         0.800647
# 4440         0.716393
# 4219         0.693028
# 3796         0.664269
# 3630         0.654159
# 6296         0.647582

# %%
print(df.columns)
# Out:
# Index(['video_id', 'author', 'likes', 'comments', 'shares', 'plays',
#        'clean_description', 'hashtag_list', 'hashtag_count', 'create_time',
#        'create_hour', 'create_day', 'create_month', 'create_year',
#        'day_of_week', 'is_weekend', 'time_period', 'total_engagement',
#        'engagement_rate_per_play', 'weighted_engagement',
#        'weighted_engagement_rate', 'commenting_rate', 'sharing_rate',
#        'viral_coefficient', 'viral_coefficient_norm', 'is_viral_plays',
#        'is_highly_engaging', 'total_engagement_capped',
#        'engagement_rate_per_play_capped', 'description_length', 'word_count',
#        'readability_score', 'sentiment_polarity', 'sentiment_subjectivity',
#        'has_question', 'has_exclamation', 'exclamation_count', 'has_tag_fyp',
#        'has_tag_viral', 'has_tag_fypシ', 'has_tag_foryoupage', 'has_tag_foryou',
#        'has_tag_trending', 'has_tag_relatable', 'has_tag_funny',
#        'has_tag_tiktok', 'has_tag_fypシviral', 'hashtag_list_clean',
#        'hashtag_categories', 'is_dance', 'is_comedy', 'is_beauty', 'is_food',
#        'is_fitness', 'is_education', 'is_pets', 'is_travel', 'is_relationship',
#        'is_music', 'is_gaming', 'is_sports', 'is_diy', 'is_fashion',
#        'content_description', 'content_cluster', 'content_category',
#        'engagement_cluster', 'engagement_pattern', 'primary_hashtag_category',
#        'unified_category', 'virality_score', 'virality_score_normalized',
#        'is_trending', 'author_avg_virality', 'author_max_virality',
#        'author_total_videos', 'author_viral_ratio', 'is_viral'],
#       dtype='object')
